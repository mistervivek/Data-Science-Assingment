# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets  
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import  DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing

# %%
comp = pd.read_csv("D:/Vivek/assingment/15 Random Forests/Company_Data.csv")

# %%
comp
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %%
comp.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
comp.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# ...

# %%
comp['Sales'] = pd.cut(x=comp['Sales'],bins=[0, 6, 12, 17], labels=['Low','Medium', 'High'], right = True)
comp['Sales']
# Out:
# 0      Medium
# 1      Medium
# 2      Medium
# 3      Medium
# 4         Low
#         ...
# 395      High
# 396    Medium
# 397    Medium
# 398       Low
# 399    Medium
# Name: Sales, Length: 400, dtype: category
# Categories (3, object): ['Low' < 'Medium' < 'High']

# %%
comp['Sales'].value_counts()
# Out:
# Medium    243
# Low       129
# High       27
# Name: Sales, dtype: int64

# %%
comp.head()
# Out:
#     Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0  Medium        138      73           11         276    120       Bad   42
# 1  Medium        111      48           16         260     83      Good   65
# 2  Medium        113      35           10         269     80    Medium   59
# 3  Medium        117     100            4         466     97    Medium   55
# 4     Low        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
label_encoder=preprocessing.LabelEncoder()

comp['CompPrice'] = pd.cut(x=comp['CompPrice'],bins=[77, 100, 133, 176], labels=['Low','Medium', 'High'], right = False)
comp['Income'] = pd.cut(x=comp['Income'],bins=[21, 46, 71, 121], labels=['Low','Medium', 'High'], right = False)
comp['Advertising'] = pd.cut(x=comp['Advertising'],bins=[0, 10, 20, 30], labels=['Low','Medium', 'High'], right = False)
comp['Population'] = pd.cut(x=comp['Population'],bins=[10, 170, 340, 510], labels=['Low','Medium', 'High'], right = False)
comp['Price'] = pd.cut(x=comp['Price'],bins=[24, 80, 136, 192], labels=['Low','Medium', 'High'], right = False)
comp['Age'] = pd.cut(x=comp['Age'],bins=[25, 45, 60, 81], labels=['Low','Medium', 'High'], right = False)
comp['Education'] = pd.cut(x=comp['Education'],bins=[10, 12.5, 15, 19], labels=['Low','Medium', 'High'], right = False)

# %%
comp
# Out:
#       Sales CompPrice  Income Advertising Population   Price ShelveLoc  \
# 0    Medium      High    High      Medium     Medium  Medium       Bad
# 1    Medium    Medium  Medium      Medium     Medium  Medium      Good
# 2    Medium    Medium     Low      Medium     Medium  Medium    Medium
# 3    Medium    Medium    High         Low       High  Medium    Medium
# 4       Low      High  Medium         Low       High  Medium       Bad
# ..      ...       ...     ...         ...        ...     ...       ...
# 395    High      High    High      Medium     Medium  Medium      Good
# 396  Medium      High     Low         Low        Low  Medium    Medium
# 397  Medium      High     Low      Medium       High    High    Medium
# 398     Low    Medium    High         Low     Medium  Medium       Bad
# 399  Medium      High     Low         Low        Low  Medium      Good
#
#         Age Education Urban   US
# 0       Low      High   Yes  Yes
# 1      High       Low   Yes  Yes
# ...

# %%
label_encoder = preprocessing.LabelEncoder()


comp['CompPrice'] = label_encoder.fit_transform(comp['CompPrice'])
comp['Income'] = label_encoder.fit_transform(comp['Income'])
comp['Advertising'] = label_encoder.fit_transform(comp['Advertising'])
comp['Population'] = label_encoder.fit_transform(comp['Population'])
comp['Price'] = label_encoder.fit_transform(comp['Price'])
comp['ShelveLoc'] = label_encoder.fit_transform(comp['ShelveLoc'])
comp['Age'] = label_encoder.fit_transform(comp['Age'])
comp['Education'] = label_encoder.fit_transform(comp['Education'])
comp['Urban'] = label_encoder.fit_transform(comp['Urban'])
comp['US'] = label_encoder.fit_transform(comp['US'])

# %%
comp['Sales'] = label_encoder.fit_transform(comp['Sales'])

# %%
comp
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0        2          0       0            2           2      2          0    1
# 1        2          2       2            2           2      2          1    0
# 2        2          2       1            2           2      2          2    2
# 3        2          2       0            1           0      2          2    2
# 4        1          0       2            1           0      2          0    1
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395      0          0       0            2           2      2          1    1
# 396      2          0       1            1           1      2          2    2
# 397      2          0       1            2           0      0          2    1
# 398      1          2       0            1           2      2          0    2
# 399      2          0       1            1           1      2          1    2
#
#      Education  Urban  US
# ...

# %%
comp.corr()
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.060307 -0.009531     0.079192    0.050072  0.101104
# CompPrice    0.060307   1.000000 -0.067776     0.023890   -0.099953  0.283602
# Income      -0.009531  -0.067776  1.000000     0.022482    0.077719 -0.031260
# Advertising  0.079192   0.023890  0.022482     1.000000    0.042640  0.066699
# Population   0.050072  -0.099953  0.077719     0.042640    1.000000 -0.001096
# Price        0.101104   0.283602 -0.031260     0.066699   -0.001096  1.000000
# ShelveLoc    0.173408  -0.032907  0.035383     0.050442    0.008897 -0.002225
# Age          0.023534  -0.020228  0.096848    -0.025986   -0.023286  0.038107
# Education   -0.023528   0.061327 -0.023920    -0.027225    0.004790  0.040300
# Urban        0.002728  -0.080875 -0.037049    -0.045881    0.076840  0.004418
# US           0.003271  -0.022295 -0.037854     0.425591    0.001007  0.039251
#
# ...

# %%
x = comp.iloc[:,1:]
y = comp['Sales']

# %%
x
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0            0       0            2           2      2          0    1
# 1            2       2            2           2      2          1    0
# 2            2       1            2           2      2          2    2
# 3            2       0            1           0      2          2    2
# 4            0       2            1           0      2          0    1
# ..         ...     ...          ...         ...    ...        ...  ...
# 395          0       0            2           2      2          1    1
# 396          0       1            1           1      2          2    2
# 397          0       1            2           0      0          2    1
# 398          2       0            1           2      2          0    2
# 399          0       1            1           1      2          1    2
#
#      Education  Urban  US
# 0            0      1   1
# 1            1      1   1
# 2            1      1   1
# ...

# %%
y
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      1
#       ..
# 395    0
# 396    2
# 397    2
# 398    1
# 399    2
# Name: Sales, Length: 400, dtype: int32

# %%
x_train, x_test,y_train,y_test = train_test_split(x,y, test_size=0.33, random_state=40)

# %% [markdown]
# Random Forest Classification

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

num_trees = 100
max_features = 'auto'
model = RandomForestClassifier(n_estimators=num_trees, max_features=max_features)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
kfold = KFold(n_splits=10)

results = cross_val_score(model, x_train, y_train, cv=kfold)
print(results.mean())
# Out:
# 0.6605413105413106

# %%
from sklearn.ensemble import BaggingClassifier

kfold = KFold(n_splits=10)
cart = DecisionTreeClassifier()
num_trees = 100
model = BaggingClassifier(base_estimator=cart, n_estimators=num_trees)
results = cross_val_score(model, x_train, y_train, cv=kfold)
print(results.mean())
# Out:
# 0.6676638176638177

# %%
from sklearn.ensemble import AdaBoostClassifier

kfold = KFold(n_splits=10)
model = AdaBoostClassifier(n_estimators=10)
results = cross_val_score(model, x_train, y_train, cv=kfold)
print(results.mean())
# Out:
# 0.6148148148148148
